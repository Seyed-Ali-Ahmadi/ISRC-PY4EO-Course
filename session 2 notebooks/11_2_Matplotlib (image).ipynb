# %% [markdown]
# ##  matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import

# %%
img=mpimg.imread('figure_skate.jpg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-73e6eba71931> in <module>()
# ----> 1 img=mpimg.imread('figure_skate.jpg')
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1358             raise ValueError('Only know how to handle extensions: %s; '
#    1359                              'with Pillow installed matplotlib can handle '
# -> 1360                              'more images' % list(handlers))
#    1361         return im
#    1362
#
# ValueError: Only know how to handle extensions: ['png']; with Pillow installed matplotlib can handle more images

# %%
img

# %%
from IPython.display import Image 
Image(filename='figure_skate.jpg')

# %%
# %matplotlib inline

# %%
plt.subplot(131)
plt.imshow(img[:,:,0], cmap='gray')
plt.subplot(132)
plt.imshow(img[:,:,1], cmap='gray')
plt.subplot(133)
plt.imshow(img[:,:,2], cmap='gray')

# %%
# %matplotlib inline
plt.imshow(img[:,:,0], cmap = 'gray', interpolation = 'bicubic')
plt.colorbar()
